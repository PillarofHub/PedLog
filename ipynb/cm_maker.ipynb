# %%
import pandas as pd
import numpy as np
import glob
import os

from sklearn.preprocessing import StandardScaler
import numpy as np

from collections import Counter

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt

# %%
cm_stay = np.array([[967,102],[75,9537]])

fig, ax = plt.subplots(figsize=(2.33, 2.33))
disp = ConfusionMatrixDisplay(cm_stay, display_labels=["Stay", "Move"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Stage 1 - Stay vs Move")
plt.tight_layout()
plt.show()

# %%
cm_move = np.array([[7529,175],[260,1648]])

fig, ax = plt.subplots(figsize=(2.5, 2.5))
disp = ConfusionMatrixDisplay(cm_move, display_labels=["Straight", "Turn"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Stage 2 - Straight vs Turn")
plt.tight_layout()
plt.show()

# %%
cm_turn = np.array([[845,22],[21,1020]])

fig, ax = plt.subplots(figsize=(2.33, 2.33))
disp = ConfusionMatrixDisplay(cm_turn, display_labels=["Left", "Right"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Stage 3 - Left vs Right")
plt.tight_layout()
plt.show()

# %%
cm_proposed = np.array(
    [
        [967,86,12,4],
        [63,7469,57,115],
        [8,103,746,10],
        [4,152,6,879]
    ])

fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_svm, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Greens', colorbar=False, values_format='d')
plt.title("Four-class classification")
plt.show()

# %%
cm_svm = np.array(
    [
        [615, 422, 31, 1],
        [69,7558,42,35],
        [21,267,579,0],
        [4,468,1,568]
    ])

fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_svm, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Reds', colorbar=False, values_format='d')
plt.title("Confusion Matrix - SVM")
plt.show()

# %%
cm_osvm = np.array(
    [
        [839,208,18,4],
        [125,7433,60,86],
        [22,215,626,4],
        [15,319,3,704]
    ])

fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_osvm, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Reds', colorbar=False, values_format='d')
plt.title("Confusion Matrix - Optimized SVM")
plt.show()

# %%
cm_sm = np.array(
    [
        [938,112,17,2],
        [119,7371,98,116],
        [24,123,710,10],
        [9,201,20,811]
    ])

fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_sm, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Blues', colorbar=False, values_format='d')
plt.title("Confusion Matrix - Single-model")
plt.show()

# %%
cm_s1 = np.array([[199,15],[14,1909]])

fig, ax = plt.subplots(figsize=(2.33, 2.33))
disp = ConfusionMatrixDisplay(cm_s1, display_labels=["Stay", "Move"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold 0 - Stay vs Move")
plt.tight_layout()
plt.show()

cm_s2 = np.array([[1501,40],[54,328]])

fig, ax = plt.subplots(figsize=(2.5, 2.5))
disp = ConfusionMatrixDisplay(cm_s2, display_labels=["Straight", "Turn"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold 0 - Straight vs Turn")
plt.tight_layout()
plt.show()

cm_s3 = np.array([[167,7],[2,206]])

fig, ax = plt.subplots(figsize=(2.33, 2.33))
disp = ConfusionMatrixDisplay(cm_s3, display_labels=["Left", "Right"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold 0 - Left vs Right")
plt.tight_layout()
plt.show()

cm_total = np.array(
    [
        [199,12,2,1],
        [13,1489,11,28],
        [0,31,142,1],
        [1,23,2,182]
    ])

fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_total, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Greens', colorbar=False, values_format='d')
plt.title("Fold 0 - Four-class classification")
plt.show()

# %%
num_fold = 1

cm_s1 = np.array([[198,16],[34,1888]])

cm_s2 = np.array([[1506,35],[47,334]])

cm_s3 = np.array([[173,0],[7,201]])

cm_total = np.array(
    [
        [198,14,1,1],
        [31,1475,15,20],
        [2,20,151,0],
        [1,26,4,177]
    ])

fig, ax = plt.subplots(figsize=(2.33, 2.33))
disp = ConfusionMatrixDisplay(cm_s1, display_labels=["Stay", "Move"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold {num_fold} - Stay vs Move")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(2.5, 2.5))
disp = ConfusionMatrixDisplay(cm_s2, display_labels=["Straight", "Turn"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold {num_fold} - Straight vs Turn")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(2.33, 2.33))
disp = ConfusionMatrixDisplay(cm_s3, display_labels=["Left", "Right"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold {num_fold} - Left vs Right")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_total, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Greens', colorbar=False, values_format='d')
plt.title(f"Fold {num_fold} - Four-class classification")
plt.show()

# %%
num_fold = 2

cm_s1 = np.array([[184,30],
                  [10,1912]
                 ])

cm_s2 = np.array([[1515,26],
                  [46,335]
                 ])

cm_s3 = np.array([[168,5],
                  [6,202]
                 ])

cm_total = np.array(
    [
        [184,30,0,0],
        [7,1508,8,18],
        [2,24,147,0],
        [1,22,2,183]
    ])

fig, ax = plt.subplots(figsize=(2.33, 2.33))
disp = ConfusionMatrixDisplay(cm_s1, display_labels=["Stay", "Move"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold {num_fold} - Stay vs Move")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(2.5, 2.5))
disp = ConfusionMatrixDisplay(cm_s2, display_labels=["Straight", "Turn"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold {num_fold} - Straight vs Turn")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(2.33, 2.33))
disp = ConfusionMatrixDisplay(cm_s3, display_labels=["Left", "Right"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold {num_fold} - Left vs Right")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_total, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Greens', colorbar=False, values_format='d')
plt.title(f"Fold {num_fold} - Four-class classification")
plt.show()

# %%
num_fold = 3

cm_s1 = np.array([[189,25],
                  [13,1909]
                 ])

cm_s2 = np.array([[1505,35],
                  [50,332]
                 ])

cm_s3 = np.array([[170,3],
                  [4,205]
                 ])

cm_total = np.array(
    [
        [189,20,1,4],
        [11,1494,11,24],
        [2,23,148,0],
        [0,26,1,182]
    ])

fig, ax = plt.subplots(figsize=(2.33, 2.33))
disp = ConfusionMatrixDisplay(cm_s1, display_labels=["Stay", "Move"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold {num_fold} - Stay vs Move")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(2.5, 2.5))
disp = ConfusionMatrixDisplay(cm_s2, display_labels=["Straight", "Turn"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold {num_fold} - Straight vs Turn")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(2.33, 2.33))
disp = ConfusionMatrixDisplay(cm_s3, display_labels=["Left", "Right"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold {num_fold} - Left vs Right")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_total, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Greens', colorbar=False, values_format='d')
plt.title(f"Fold {num_fold} - Four-class classification")
plt.show()

# %%
num_fold = 4

cm_s1 = np.array([[192,21],
                  [16,1907]
                 ])

cm_s2 = np.array([[1509,32],
                  [37,345]
                 ])

cm_s3 = np.array([[169,5],
                  [4,204]
                 ])

cm_total = np.array(
    [
        [192,18,2,1],
        [13,1496,13,19],
        [1,13,155,5],
        [2,22,1,183]
    ])

fig, ax = plt.subplots(figsize=(2.33, 2.33))
disp = ConfusionMatrixDisplay(cm_s1, display_labels=["Stay", "Move"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold {num_fold} - Stay vs Move")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(2.5, 2.5))
disp = ConfusionMatrixDisplay(cm_s2, display_labels=["Straight", "Turn"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold {num_fold} - Straight vs Turn")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(2.33, 2.33))
disp = ConfusionMatrixDisplay(cm_s3, display_labels=["Left", "Right"])
disp.plot(ax=ax, cmap='Greens', values_format='d', colorbar=False)
plt.title(f"Fold {num_fold} - Left vs Right")
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_total, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Greens', colorbar=False, values_format='d')
plt.title(f"Fold {num_fold} - Four-class classification")
plt.show()

# %%
model_name="SVM"

cm_f0 = np.array(
    [
        [126,79,9,0],
        [12,1514,8,7],
        [4,56,114,0],
        [1,86,1,120]
    ])
cm_f1 = np.array(
    [
        [125,82,7,0],
        [20,1505,9,7],
        [6,58,109,0],
        [3,100,0,105]
    ])
cm_f2 = np.array(
    [
        [122,87,5,0],
        [14,1512,8,7],
        [1,52,120,0],
        [0,88,0,120]
    ])
cm_f3 = np.array(
    [
        [119,89,5,1],
        [11,1511,9,9],
        [5,45,123,0],
        [0,87,0,122]
    ])
cm_f4 = np.array(
    [
        [123,85,5,0],
        [12,1516,8,5],
        [5,56,113,0],
        [0,107,0,101]
    ])

num_fold = 0
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f0, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Reds', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

num_fold = num_fold + 1
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f1, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Reds', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

num_fold = num_fold + 1
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f2, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Reds', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

num_fold = num_fold + 1
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f3, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Reds', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

num_fold = num_fold + 1
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f4, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Reds', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

# %%
model_name="Optimized SVM"

cm_f0 = np.array(
    [
        [166,43,5,0],
        [19,1494,9,19],
        [6,48,120,0],
        [1,53,2,152]
    ])
cm_f1 = np.array(
    [
        [177,35,2,0],
        [36,1478,9,18],
        [4,48,121,0],
        [7,68,1,132]
    ])
cm_f2 = np.array(
    [
        [161,49,3,1],
        [26,1482,12,21],
        [3,45,125,0],
        [1,64,0,143]
    ])
cm_f3 = np.array(
    [
        [163,45,4,2],
        [22,1489,18,11],
        [5,35,132,1],
        [2,65,0,142]
    ])
cm_f4 = np.array(
    [
        [172,36,4,1],
        [22,1490,12,17],
        [4,39,128,3],
        [4,69,0,135]
    ])

num_fold = 0
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f0, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Reds', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

num_fold = num_fold + 1
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f1, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Reds', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

num_fold = num_fold + 1
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f2, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Reds', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

num_fold = num_fold + 1
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f3, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Reds', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

num_fold = num_fold + 1
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f4, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Reds', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

# %%
model_name="Single-model classifier"

cm_f0 = np.array(
    [
        [181,31,2,0],
        [13,1497,13,18],
        [5,34,134,1],
        [1,41,2,164]
    ])
cm_f1 = np.array(
    [
        [194,17,3,0],
        [45,1472,13,11],
        [9,32,128,4],
        [5,49,0,154]
    ])
cm_f2 = np.array(
    [
        [193,19,2,0],
        [22,1470,24,25],
        [4,20,147,2],
        [2,28,5,173]
    ])
cm_f3 = np.array(
    [
        [173,31,8,2],
        [16,1458,24,42],
        [2,14,154,3],
        [0,31,2,176]
    ])
cm_f4 = np.array(
    [
        [197,14,2,0],
        [24,1474,24,20],
        [4,23,147,0],
        [1,52,11,144]
    ])

num_fold = 0
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f0, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Blues', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

num_fold = num_fold + 1
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f1, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Blues', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

num_fold = num_fold + 1
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f2, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Blues', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

num_fold = num_fold + 1
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f3, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Blues', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()

num_fold = num_fold + 1
fig, ax = plt.subplots(figsize=(4, 4))
disp_total = ConfusionMatrixDisplay(confusion_matrix=cm_f4, display_labels=["Stay", "Straight", "Left", "Right"])
disp_total.plot(ax=ax, cmap='Blues', colorbar=False, values_format='d')
plt.title(f"{model_name} - Fold {num_fold}")
plt.show()
